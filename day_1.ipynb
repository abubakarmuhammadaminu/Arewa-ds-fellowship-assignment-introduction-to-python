# %%
message = "I love Habiba Abubakar Danladi"
print(message)
# Out:
# I love Habiba Abubakar Danladi

# %%
message_2 = "My name is Muhammad Aminu Abubakar"
print(message_2)
# Out:
# My name is Muhammad Aminu Abubakar

# %%
message_2 = "My name is Muhammad Aminu Abubakar Kusfa"
print(message_2)
# Out:
# My name is Muhammad Aminu Abubakar Kusfa
