# %%
address = ("338 Anguwan Danjinjiri \nZaria city \nKaduna state")   # TODO

print(address)
# Out:
# 338 Anguwan Danjinjiri
# Zaria city
# Kaduna state

# %%
address2 = """338 Anguwan Danjinjiri Zaria city Kaduna state
338 Anguwan Danjinjiri Zaria city Kaduna state
338 Anguwan Danjinjiri Zaria city Kaduna state"""   # TODO

print(address2)
# Out:
# 338 Anguwan Danjinjiri Zaria city Kaduna state
# 338 Anguwan Danjinjiri Zaria city Kaduna state
# 338 Anguwan Danjinjiri Zaria city Kaduna state

# %%
print("First line\nSecond line")
# Out:
# First line
# Second line

# %%
print(type(42))
print(type(3.14))
print(type("42"))
print(type(""))
print(type('A'))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
count    = 6  # TODO: the integer 25
price    = 6.0   # TODO: the float 25.0
label    = ("6")   # TODO: the string 25
blank    = (" ")  # TODO: the empty string

# %%
print("Hi " + "there, " + "Aisha!")
print(" " * 10 + "Python")
print("-" * 40)
print(len("Kano"))
# Out:
# Hi there, Aisha!
#           Python
# ----------------------------------------
# 4

# %%
title = "ArewaDS"
banner ="*" * 5 + " " + title + " " + 5 * "*" # TODO

print(banner)
# Out:
# ***** ArewaDS *****

# %%
# TODO: fix the line above so it prints  Age: 25
age = str(25)
print("Age: " + age)
# Out:
# Age: 25

# %%
firstName = "Ken"
secondName = "Lambert"
fullName = firstName + " " + secondName
print(fullName)

# variables can be reset
firstName = "Amina"
fullName = firstName + " " + secondName
print(fullName)
# Out:
# Ken Lambert
# Amina Lambert

# %%
ndPlace = "silver"

# %%
name = 10

# %%
student_name = "Fatima"

# %%
score = 10
Score = 20
print(score, Score, score + Score)
# Out:
# 10 20 30

# %%
VAT_RATE = 0.075       # TODO: define the constant
amount = 12000
vat = VAT_RATE * amount   # TODO

print(vat)
# Out:
# 900.0

# %%
# TODO: add a docstring above this line and comments inside

RATE = 0.70
amountCAD = 250.0
amountUSD = amountCAD * RATE
print("US dollars:", amountUSD)
# Out:
# US dollars: 175.0

# %%
doc = """ This program computes the area of a
 Input: The radius of the circle.
 Output: The calculated area. """   # TODO: use a triple-quoted string

print(doc)
# Out:
#  This program computes the area of a
#  Input: The radius of the circle.
#  Output: The calculated area.

# %%
print(2 + 3 * 4)
print((2 + 3) * 4)
print(2 ** 3 ** 2)
print(-2 ** 2)
print(17 / 5)
print(17 // 5)
print(17 % 5)
print(-17 // 5)
# Out:
# 14
# 20
# 512
# -4
# 3.4
# 3
# 2
# -4

# %%
totalSeconds = 7385

hours   = totalSeconds // 3600   # TODO
minutes = (totalSeconds // 60) % 60   # TODO
seconds = totalSeconds % 60   # TODO

print(hours, "h", minutes, "m", seconds, "s")
# Out:
# 2 h 3 m 5 s

# %%
a, b, c = 70, 80, 90
average = (a + b + c) / 3   # TODO: fix with parentheses

print(average)
# Out:
# 80.0

# %%
result = 3 + 4 * \
         2 ** 5
print(result)
# Out:
# 131

# %%
print(3.14 * 3 ** 2)     # mixed int and float
print(int(3.77))
print(int("33"))
print(float(22))
print(str(99) + "9")
# Out:
# 28.26
# 3
# 33
# 22.0
# 999

# %%
print(int(6.75), round(6.75))
print(int(-6.75), round(-6.75))
print(round(2.5), round(3.5))
# Out:
# 6 7
# -6 -7
# 2 4

# %%
profit = str("1000.55")
print('$' + profit)
# Out:
# $1000.55

# %%
number = int(input("Enter a number: "))
print("Your number doubled is:", number * 2)
# Out:
# Your number doubled is: 12

# %%
import math

radius = 5
area = math.pi * (radius ** 2)        # TODO

hypotenuse = math.sqrt(3**2 + 4**2) # TODO

print(area, hypotenuse)
# Out:
# 78.53981633974483 5.0

# %%
import math

piRounded = round(math.pi, 4)   # TODO
print(piRounded)
# Out:
# 3.1416

# %% [markdown]
# # Assignment

# %% [markdown]
# ## EXC 1

# %% [markdown]
# 1. 1
# 2. 7
# 3. 2
# 4. 555
# 5. 3
# 6. 15
# 7. 4
# 8. float
# 9. false

# %% [markdown]
# ## EXC 2

# %%
# should print:  Total: 150
subtotal = 100
tax = 50
print("Total: ", subtotal + tax)
# Out:
# Total:  150

# %% [markdown]
# ## EXC 3

# %%
# should print the average, 15.0
total = 45
Count = 3
print(total / Count)
# Out:
# 15.0

# %% [markdown]
# ## EXC 4

# %%
# should print:  Half of 7 is 3.5
n = 7
print("Half of " + str(n) + " is " + str(n / 2))
# Out:
# Half of 7 is 3.5

# %% [markdown]
# ## EXC 5

# %%
amountKobo = 27350

notes100 = amountKobo // 10000  # TODO
notes50  =  (amountKobo % 10000) // 5  # TODO
leftoverKobo = amountKobo % 5000   # TODO

print(notes100, "x 100 naira,", notes50, "x 50 naira, and", leftoverKobo, "kobo left over")
# Out:
# 2 x 100 naira, 1470 x 50 naira, and 2350 kobo left over

# %% [markdown]
# ## EXC 6

# %%
item = "Rice"
quantity = 3
unitPrice = 1500.0

line = item + " X " + str(quantity) + " = " + str(quantity * unitPrice) + " naira"  # TODO

print(line)
# Out:
# Rice X 3 = 4500.0 naira

# %% [markdown]
# ## EXC 7

# %%
principal = 50000.0
rate = 0.12
years = 5

balance = round(principal * (1 + rate) ** years, 2)   # TODO

print("Balance after", years, "years:", balance)
# Out:
# Balance after 5 years: 88117.08

# %% [markdown]
# ## EXC 8

# %%
# TODO: your program here
""""This program calculates the circumferance and area of a circle
based on a radius provided by the user"""

import math

radius = float(input("Enter the radius of a circle: "))

circumferance = 2 * math.pi * radius

area = math.pi * (radius ** 2)

print("Circumferance: " + str(circumferance))
print("Area: " + str(area))
# Out:
# Circumferance: 75.39822368615503
# Area: 452.3893421169302
