# %%
print("Muhammad Aminu Abubakar")
# Out:
# Muhammad Aminu Abubakar

# %%
print("Muhammad Aminu Abubakar")
print("Habiba Abubakar")
# Out:
# Muhammad Aminu Abubakar
# Habiba Abubakar

# %%
print(157)
# Out:
# 157

# %%
print("I am learning python")
# Out:
# I am learning python

# %%
print(25 + 17)
# Out:
# 42

# %%
city = "Zaria city"
temperature = 37
num_1 = 6
num_2 = 5
sum_result = num_1 + num_2
print(city)
print(temperature)
print(sum_result)
# Out:
# Zaria city
# 37
# 11

# %%
length = int(input("What is the length of reactangle? "))
width = int(input("What is the width of reactangle? "))
area = (length * width)
print(area)
# Out:
# 20

# %%
first_name = input("What is your surname? ")
second_name = input("  What is your other name? ")
message = "Welcome " + first_name + second_name
print(message)
# Out:
# Welcome Muhammad AminuAbubakar

# %%
length = input("What is the length of reactangle? ")
width = input("What is the width of reactangle? ")
area = (length + width)
print(area)
# wrong
# Out:
# 56

# %%
temperature_celsius = int(input("What is the temperature today? "))
temperature_farenheit = (temperature_celsius * 9/5) + 32
print(temperature_farenheit)
# Out:
# 113.0

# %%
num_1 = int(input("Put a number "))
num_2 = int(input("Put a number "))
print(num_1 + num_2)
print(num_2 - num_1)
print(num_1 * num_2)
print(num_2**3)
print(num_1**3)
# Out:
# 10
# 2
# 24
# 216
# 64

# %%
name = input("What is your name? ")
age = int(input("How old are you? "))
years_to_1oo = 100 - age
print("Hello ", name )
print("You will be 100 years old in ", years_to_1oo, "years!")
# Out:
# Hello  Muhammad Aminu
# You will be 100 years old in  67 years!

# %% [markdown]
# # Assignment

# %%
#Area calculator
length = int(input("What is the length of reactangle?  "))
width = int(input("What is the width of reactangle?  "))
area = length * width
perimeter = 2*(length + width)
print(area)
print(perimeter)
# Out:
# 35
# 24

# %%
first_name = input("What is your first name? ")
second_name = input("What is your second name? ")
age = input("How old are you? ")
favourite_color = input("What is your favourite hobby? ")
message = (first_name +  " " +  second_name + " is " +  age + " years old " + " " +  favourite_color + " enthusiate. ")
print(message)
# Out:
# Muhammad Aminu Abubakar is 33 years old  Data sceince and ML enthusiate.

# %%
maize = int(input("What is the price of maize? "))
beans = int(input("What is the price of beans? "))
rice = int(input("What is the price of rice? "))
subtotal = (maize + beans + rice)
sales_tax = subtotal * 0.06
final_total = subtotal + sales_tax
print("$",subtotal)
print("$",sales_tax)
print("$",final_total)
# Out:
# $ 6000
# $ 360.0
# $ 6360.0

# %% [markdown]
# # Assignment 2

# %%
address = ("1338 Anguwan Danjinjiri \nZaria city \nKaduna state")   # TODO

print(address)
# Out:
# 1338 Anguwan Danjinjiri
# Zaria city
# Kaduna state

# %%
print(round(3.75))
# Out:
# 4
